# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style="white", context="talk")

plt.rcParams["font.sans-serif"] = [
    "Arial Unicode MS",   # macOS 常见，兼容性好
    "PingFang SC",        # macOS
    "Heiti SC",           # macOS
    "SimHei",             # Windows
    "Microsoft YaHei",    # Windows
    "Noto Sans CJK SC",   # Linux
    "WenQuanYi Micro Hei" # Linux
]
plt.rcParams["axes.unicode_minus"] = False  # 防止负号显示成方块

plt.rcParams["figure.dpi"] = 300
plt.rcParams["savefig.dpi"] = 300
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"

BASE_DIR = Path.cwd()
if BASE_DIR.name != "src":
    BASE_DIR = BASE_DIR / "src"

TIME_PATH = BASE_DIR / "result" / "time.csv"
FIG_DIR = BASE_DIR / "result" / "figures"
FIG_DIR.mkdir(parents=True, exist_ok=True)

time_df = pd.read_csv(TIME_PATH)
METHOD_ORDER = ["BP", "RK", "ABRA", "SILVAN", "GPU_SIR_BRIDGE"]
DISPLAY_METHOD_ORDER = ["BP", "RK", "ABRA", "SILVAN", "FastBC"]
BAR_COLORS = ["#4C78A8", "#F58518", "#54A24B", "#E45756", "#72B7B2"]

time_df.head()
# Out:
#         graph_name graph_source  num_nodes  num_edges  epsilon  top_k  \
# 0         Celegans         real        297       2148      0.2     30
# 1        Fb-tvshow         real       3892      17262      0.2    390
# 2           Router         real       5022       6258      0.2    503
# 3  Soc-hamsterster         real       2000      16097      0.2    200
# 4            Yeast         real       2375      11693      0.2    238
#
#    top_k_ratio  exact_time        BP        RK       ABRA     SILVAN  \
# 0          0.1    0.187953  0.032618  0.049157   0.300889   1.067299
# 1          0.1  199.501414  9.916932  6.831200  13.151801  42.717876
# 2          0.1  163.628969  4.877051  2.849069  20.966406  50.863380
# 3          0.1   10.774516  0.731323  0.475777   1.266136   3.525795
# 4          0.1   12.728102  0.684447  0.492066   2.171698   4.311059
#
#    GPU_SIR_BRIDGE
# 0        0.335831
# 1        0.213401
# 2        0.114331
# 3        0.382132
# 4        0.073723

# %%
EPSILON = 0.2

GRAPH_GROUPS = {
    "Real": ["bitcoin-alpha", "wiki-Vote",  "p2p-Gnutella06", "Soc-hamsterster"],
    "BA": ["BA1000", "BA2000", "BA3000", "BA5000"],
    "WS": ["WS1000", "WS2000", "WS3000", "WS5000"],
    "ER": ["ER1000", "ER2000", "ER3000", "ER5000"],
}

GRAPH_SOURCE = {
    "Real": "real",
    "BA": "synthetic",
    "WS": "synthetic",
    "ER": "synthetic",
}

available_real = sorted(time_df.loc[time_df["graph_source"] == "real", "graph_name"].unique())
available_synthetic = sorted(time_df.loc[time_df["graph_source"] == "synthetic", "graph_name"].unique())

print("Available real graphs:")
print(available_real)
print()
print("Available synthetic graphs:")
print(available_synthetic)
# Out:
# Available real graphs:
# ['Celegans', 'Fb-tvshow', 'Router', 'Soc-hamsterster', 'Yeast', 'bitcoin-alpha', 'ca-GrQc', 'cora', 'p2p-Gnutella06', 'wiki-Vote']
#
# Available synthetic graphs:
# ['BA1000', 'BA10000', 'BA2000', 'BA3000', 'BA5000', 'ER1000', 'ER2000', 'ER3000', 'ER5000', 'WS1000', 'WS2000', 'WS3000', 'WS5000']

# %%
plot_df = time_df.loc[time_df["epsilon"] == EPSILON].copy()
all_times = plot_df[METHOD_ORDER].astype(float).to_numpy().ravel()
positive_times = all_times[all_times > 0]
y_min = positive_times.min() * 0.55
y_max = positive_times.max() * 1.9


def format_time_label(value):
    if value < 0.1:
        return f"{value:.3f}"
    if value < 10:
        return f"{value:.2f}"
    if value < 100:
        return f"{value:.1f}"
    return f"{value:.0f}"


fig, axes = plt.subplots(4, 4, figsize=(20, 24), sharey=True)
fig.suptitle("不同网络类型下各中心性算法的运行时间对比", fontsize=28, fontweight="bold", y=0.97)

for row_idx, (group_name, graph_names) in enumerate(GRAPH_GROUPS.items()):
    expected_source = GRAPH_SOURCE[group_name]
    for col_idx, graph_name in enumerate(graph_names):
        ax = axes[row_idx, col_idx]
        row = plot_df.loc[
            (plot_df["graph_source"] == expected_source)
            & (plot_df["graph_name"] == graph_name)
        ]

        if row.empty:
            ax.set_axis_off()
            ax.text(0.5, 0.5, f"Missing\n{graph_name}", ha="center", va="center", fontsize=16, fontweight="bold")
            continue

        values = row.iloc[0][METHOD_ORDER].astype(float)
        bars = ax.bar(DISPLAY_METHOD_ORDER, values, color=BAR_COLORS, width=0.72)
        ax.set_title(graph_name, fontsize=18, fontweight="bold", pad=12)
        ax.set_yscale("log")
        ax.set_ylim(y_min, y_max)
        ax.tick_params(axis="x", rotation=28, labelsize=13)
        ax.tick_params(axis="y", labelsize=13)
        ax.grid(False)
        for label in ax.get_xticklabels() + ax.get_yticklabels():
            label.set_fontweight("bold")

        if col_idx == 0:
            ax.set_ylabel("Time (s)", fontsize=16, fontweight="bold")

        for bar, value in zip(bars, values):
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                value * 1.12,
                format_time_label(value),
                ha="center",
                va="bottom",
                fontsize=11,
                fontweight="bold",
                rotation=0,
            )

plt.tight_layout(rect=[0, 0, 1, 0.97])
save_path = FIG_DIR / "time_bar_grid_4x4.png"
fig.savefig(save_path, bbox_inches="tight")
print(f"Saved figure to: {save_path}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 18
#      14         return f"{value:.1f}"
#      15     return f"{value:.0f}"
# ---> 18 fig, axes = plt.subplots(4, 4, figsize=(20, 24), sharey=True)
#      19 fig.suptitle("不同网络类型下各中心性算法的运行时间对比", fontsize=28, fontweight="bold", y=0.97)
#      21 for row_idx, (group_name, graph_names) in enumerate(GRAPH_GROUPS.items()):
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/pyplot.py:1599, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1455 """
#    1456 Create a figure and a set of subplots.
#    1457
#    (...)
#    1596
#    1597 """
#    1598 fig = figure(**fig_kw)
# -> 1599 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1600                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1601                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1602                    width_ratios=width_ratios)
#    1603 return fig, axs
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/figure.py:931, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     928     gridspec_kw['width_ratios'] = width_ratios
#     930 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 931 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     932                   subplot_kw=subplot_kw)
#     933 return axs
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/gridspec.py:298, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     296         subplot_kw["sharex"] = shared_with[sharex]
#     297         subplot_kw["sharey"] = shared_with[sharey]
# --> 298         axarr[row, col] = figure.add_subplot(
#     299             self[row, col], **subplot_kw)
#     301 # turn off redundant tick labeling
#     302 if sharex in ["col", "all"]:
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/figure.py:782, in FigureBase.add_subplot(self, *args, **kwargs)
#     780         args = tuple(map(int, str(args[0])))
#     781     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 782     ax = projection_class(self, *args, **pkw)
#     783     key = (projection_class, pkw)
#     784 return self._add_axes_internal(ax, key)
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/axes/_base.py:678, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     675 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     677 self._rasterization_zorder = None
# --> 678 self.clear()
#     680 # funcs used to format x and y - fall back on major formatters
#     681 self.fmt_xdata = None
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/axes/_base.py:1388, in _AxesBase.clear(self)
#    1386     self.cla()
#    1387 else:
# -> 1388     self.__clear()
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/axes/_base.py:1356, in _AxesBase.__clear(self)
#    1353 self.set_axis_on()
#    1355 self.xaxis.set_clip_path(self.patch)
# -> 1356 self.yaxis.set_clip_path(self.patch)
#    1358 if self._sharex is not None:
#    1359     self.xaxis.set_visible(xaxis_visible)
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/axis.py:1111, in Axis.set_clip_path(self, path, transform)
#    1108 @_api.rename_parameter("3.8", "clippath", "path")
#    1109 def set_clip_path(self, path, transform=None):
#    1110     super().set_clip_path(path, transform)
# -> 1111     for child in self.majorTicks + self.minorTicks:
#    1112         child.set_clip_path(path, transform)
#    1113     self.stale = True
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/axis.py:591, in _LazyTickList.__get__(self, instance, owner)
#     589 else:
#     590     instance.minorTicks = []
# --> 591     tick = instance._get_tick(major=False)
#     592     instance.minorTicks.append(tick)
#     593     return instance.minorTicks
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/axis.py:1562, in Axis._get_tick(self, major)
#    1558     raise NotImplementedError(
#    1559         f"The Axis subclass {self.__class__.__name__} must define "
#    1560         "_tick_class or reimplement _get_tick()")
#    1561 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1562 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/axis.py:470, in YTick.__init__(self, *args, **kwargs)
#     469 def __init__(self, *args, **kwargs):
# --> 470     super().__init__(*args, **kwargs)
#     471     # x in axes coords, y in data coords
#     472     ax = self.axes
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/axis.py:170, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     160 self.tick1line = mlines.Line2D(
#     161     [], [],
#     162     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     163     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     164 )
#     165 self.tick2line = mlines.Line2D(
#     166     [], [],
#     167     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     168     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     169 )
# --> 170 self.gridline = mlines.Line2D(
#     171     [], [],
#     172     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     173     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     174     **grid_kw,
#     175 )
#     176 self.gridline.get_path()._interpolation_steps = \
#     177     GRIDLINE_INTERPOLATION_STEPS
#     178 self.label1 = mtext.Text(
#     179     np.nan, np.nan,
#     180     fontsize=labelsize, color=labelcolor, visible=label1On,
#     181     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
#
# File ~/anaconda3/envs/mdp/lib/python3.10/site-packages/matplotlib/lines.py:287, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     283     else:
#     284         return "Line2D(%s)" % ",".join(
#     285             map("({:g},{:g})".format, self._x, self._y))
# --> 287 def __init__(self, xdata, ydata, *,
#     288              linewidth=None,  # all Nones default to rc
#     289              linestyle=None,
#     290              color=None,
#     291              gapcolor=None,
#     292              marker=None,
#     293              markersize=None,
#     294              markeredgewidth=None,
#     295              markeredgecolor=None,
#     296              markerfacecolor=None,
#     297              markerfacecoloralt='none',
#     298              fillstyle=None,
#     299              antialiased=None,
#     300              dash_capstyle=None,
#     301              solid_capstyle=None,
#     302              dash_joinstyle=None,
#     303              solid_joinstyle=None,
#     304              pickradius=5,
#     305              drawstyle=None,
#     306              markevery=None,
#     307              **kwargs
#     308              ):
#     309     """
#     310     Create a `.Line2D` instance with *x* and *y* data in sequences of
#     311     *xdata*, *ydata*.
#    (...)
#     320
#     321     """
#     322     super().__init__()
#
# KeyboardInterrupt:
